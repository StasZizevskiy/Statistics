# %%
import matplotlib.pyplot as plt
from scipy.stats import linregress
import pandas as pd
import seaborn as sns

# %%
dataframe = pd.read_csv('D:/Статистика/Data/states.csv')
dataframe.head()
# Out:
#         state  metro_res  white  hs_grad  poverty  female_house
# 0     Alabama       55.4   71.3     79.9     14.6          14.2
# 1      Alaska       65.6   70.8     90.6      8.3          10.8
# 2     Arizona       88.2   87.7     83.8     13.3          11.1
# 3    Arkansas       52.5   81.0     80.9     18.0          12.1
# 4  California       94.4   77.5     81.1     12.8          12.6

# %%
corr = dataframe.corr(method='spearman', numeric_only=True)
sns.heatmap(corr)

plt.show()

# %%
sns.scatterplot(x='hs_grad', y='poverty', data=dataframe, size='white')
# Out:
# <Axes: xlabel='hs_grad', ylabel='poverty'>

# %%
sns.jointplot(x='hs_grad', y='poverty', data=dataframe, kind='reg')
# Out:
# C:\Users\ZeVS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ZeVS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
