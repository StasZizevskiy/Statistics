# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('D:/Статистика/Data/states.csv')
df.head()
# Out:
#         state  metro_res  white  hs_grad  poverty  female_house
# 0     Alabama       55.4   71.3     79.9     14.6          14.2
# 1      Alaska       65.6   70.8     90.6      8.3          10.8
# 2     Arizona       88.2   87.7     83.8     13.3          11.1
# 3    Arkansas       52.5   81.0     80.9     18.0          12.1
# 4  California       94.4   77.5     81.1     12.8          12.6

# %% [markdown]
# metro_res - процент населения живущие в столице
# white - процент белого населения
# hs_grad - процент людей со образованием
# poverty - уровень бедности
# female_house - процент домов, где есть домохозяйки

# %%
sns.jointplot(x='hs_grad', y='poverty', data=df, dropna=True, kind='reg', color='g', palette='YlGnBu')
plt.show()
# Out:
# C:\Users\ZeVS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ZeVS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df_descr = df.describe().transpose()
df_descr
# Out:
#               count       mean        std   min    25%   50%    75%    max
# metro_res      51.0  72.249020  15.275894  38.2  60.80  71.6  86.80  100.0
# white          51.0  81.719608  13.897223  25.9  76.80  85.4  90.25   97.1
# hs_grad        51.0  86.011765   3.725998  77.2  83.30  86.9  88.70   92.1
# poverty        51.0  11.349020   3.099185   5.6   9.25  10.6  13.40   18.0
# female_house   51.0  11.633333   2.356155   7.8   9.55  11.8  12.65   18.9

# %%
from scipy.stats import linregress

slope, intercept, r, p, std_err =  linregress(df['hs_grad'], df['poverty'])

x = np.linspace(75, 100)

reg = lambda x: intercept + slope*x
plt.scatter(x='hs_grad', y='poverty', data=df, label='data')
plt.xlabel('hs_grad%')
plt.ylabel('poverty%')
plt.title('Linear Regression')
plt.plot(x, reg(x), color='r', label='fitted line')
plt.legend()
plt.show()

# %%
print(f'''
slope = {slope:.2f}  #угол наклона регрессионной прямой
intercept = {intercept:.2f} #точка пересечения с осью Y 
r = {r:.2f} #коэффициент регрессии
r squared = {(r ** 2):.2f} #коэффициент детерминации
p = {p:.5f} #уровень значимости
std_err = {std_err:.3f} #ошибка среднего
''')
# Out:
# slope = -0.62  #угол наклона регрессионной прямой
# intercept = 64.78 #точка пересечения с осью Y
# r = -0.75 #коэффициент регрессии
# r squared = 0.56 #коэффициент детерминации
# p = 0.00000 #уровень значимости
# std_err = 0.079 #ошибка среднего
